# %% [markdown]
# #🧾 Pre-Entrega
#
#
# *   Amahia Guadalupe Lucía Páez
# *   Comisión: *25262*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
#Cargo los datasets y guardo las rutas
ruta_ventas = "/content/drive/MyDrive/Colab Notebooks/datasets/ventas.csv";
ruta_marketing = "/content/drive/MyDrive/Colab Notebooks/datasets/marketing.csv";
ruta_clientes = "/content/drive/MyDrive/Colab Notebooks/datasets/clientes.csv";

# %%
#cargo lo cvs como datframe
clientes = pd.read_csv(ruta_clientes);
ventas = pd.read_csv(ruta_ventas);
marketing = pd.read_csv(ruta_marketing);

#Compruebo los dataframe usando head para ver las primeras 5 columnss

print("------------------------------- Clientes -------------------------------")
display(clientes.head())
print("------------------------------- Ventas -------------------------------")
display(ventas.head())
print("------------------------------ Marketing -------------------------------")
display(marketing.head())
# Out:
# ------------------------------- Clientes -------------------------------
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# ------------------------------- Ventas -------------------------------
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# ...

# %%
print(f"Clientes: {clientes.shape}")
print(f"Ventas: {ventas.shape}")
print(f"Marketing: {marketing.shape}")
# Out:
# Clientes: (567, 5)
# Ventas: (3035, 6)
# Marketing: (90, 6)

# %% [markdown]
# ### Exploración de datos - EDA

# %%
'''
Funcion eda que mostrara: Tipos de datos, cantidad de valores nulos, las 5 primeras filas
cantidad de filas y columnas, estadistica descriptiva, valores duplicados
'''
def exploracion_de_datos(data, data_nombre):
  print("Info general del dataset: ")
  print(data.info);
  print("Primeras filas: ")
  print(data.head())
  print("Dimenciones del dataset: ")
  print(f"Filas: {data.shape[0]} | Columnas: {data.shape[1]}")
  print("Estadistica descriptivaa: ")
  print(data.describe);
  print("Valores nulos: ")
  print(data.isnull().sum());
  print("Valores duplicados: ")
  print(data.duplicated().sum());

# %%
#invoco la funcion de eda
exploracion_de_datos(clientes, "Clientes")
# Out:
# Info general del dataset:
# <bound method DataFrame.info of      id_cliente               nombre  edad         ciudad  ingresos
# 0             1      Aloysia Screase    44  Mar del Plata  42294.68
# 1             2  Kristina Scaplehorn    25        Posadas  24735.04
# 2             3       Filip Castagne    50    Resistencia  35744.85
# 3             4          Liuka Luard    39   Bahía Blanca  27647.96
# 4             5        Dore Cockshtt    28        Rosario  28245.65
# ..          ...                  ...   ...            ...       ...
# 562         563        Dione Forsyde    29        Posadas  26757.73
# 563         564          Fleming Gow    39       Santa Fe  43674.96
# 564         565      Jewelle Mabbett    33        Córdoba  30522.64
# 565         566          Lauri Munns    23    Resistencia  31259.14
# 566         567          Micah Matis    31     Corrientes  42927.86
#
# [567 rows x 5 columns]>
# Primeras filas:
# ...

# %%
exploracion_de_datos(ventas, "Ventas")
# Out:
# Info general del dataset:
# <bound method DataFrame.info of       id_venta                producto   precio  cantidad fecha_venta  \
# 0          792       Cuadro decorativo   $69.94       5.0  02/01/2024
# 1          811         Lámpara de mesa  $105.10       5.0  02/01/2024
# 2         1156                Secadora   $97.96       3.0  02/01/2024
# 3         1372                Heladera  $114.35       8.0  02/01/2024
# 4         1546                Secadora  $106.21       4.0  02/01/2024
# ...        ...                     ...      ...       ...         ...
# 3030      1837         Horno eléctrico  $104.12       9.0  30/12/2024
# 3031      2276                  Laptop   $85.27       9.0  30/12/2024
# 3032      2696                  Laptop  $107.81       4.0  30/12/2024
# 3033      2913              Smartphone   $99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   $55.47       6.0  30/12/2024
#
#               categoria
# 0            Decoración
# ...

# %%
exploracion_de_datos(marketing, "Marketing")
# Out:
# Info general del dataset:
# <bound method DataFrame.info of     id_campanha            producto  canal  costo fecha_inicio   fecha_fin
# 0            74     Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1            12              Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2            32     Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3            21          Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4            58            Alfombra  Email   4.25   31/03/2024  05/05/2024
# ..          ...                 ...    ...    ...          ...         ...
# 85           70          Aspiradora     TV   3.06   13/12/2024  29/12/2024
# 86           89           Televisor     TV   4.98   13/12/2024    8/2/2025
# 87           68   Rincón de plantas     TV   5.81   17/12/2024   14/2/2025
# 88           33            Secadora  Email   3.80   20/12/2024    7/1/2025
# 89           11  Freidora eléctrica   RRSS   5.27   29/12/2024   21/1/2025
#
# ...

# %% [markdown]
# ### Calidad de datos

# %%
def revisar_calidad_de_datos(data, dataNombre):
    '''
    Revisa la calidad de los datos devolviendo un reporte de datos nulos, tiposd e datos y valores unicos por columna
    '''
    print(f"------------- Dataset de {dataNombre} -------------")
    duplicados = data.duplicated().sum()
    print(f"Cantidad de duplicados: {duplicados}")
    print("----------------------------------------")
    tipos_de_datos = data.dtypes;
    nulos = data.isnull().sum();
    porcentaje_nulos = (nulos / len(data)) *100;
    unicos = data.nunique();

    reporte = pd.DataFrame({
        "Tipo de dato": tipos_de_datos,
        "Cantidad de nulos": nulos,
        "Porcentaje de nulos": porcentaje_nulos,
        "Cantidad de valores unicos": unicos
    })
    return reporte;

# %%
revisar_calidad_de_datos(clientes, "Clientes")
# Out:
# ------------- Dataset de Clientes -------------
# Cantidad de duplicados: 0
# ----------------------------------------
#            Tipo de dato  Cantidad de nulos  Porcentaje de nulos  \
# id_cliente        int64                  0                  0.0
# nombre           object                  0                  0.0
# edad              int64                  0                  0.0
# ciudad           object                  0                  0.0
# ingresos        float64                  0                  0.0
#
#             Cantidad de valores unicos
# id_cliente                         567
# nombre                             567
# edad                                49
# ciudad                              12
# ingresos                           547

# %%
revisar_calidad_de_datos(ventas, "Ventas")
# Out:
# ------------- Dataset de Ventas -------------
# Cantidad de duplicados: 35
# ----------------------------------------
#             Tipo de dato  Cantidad de nulos  Porcentaje de nulos  \
# id_venta           int64                  0             0.000000
# producto          object                  0             0.000000
# precio            object                  2             0.065898
# cantidad         float64                  2             0.065898
# fecha_venta       object                  0             0.000000
# categoria         object                  0             0.000000
#
#              Cantidad de valores unicos
# id_venta                           3000
# producto                             30
# precio                             2590
# cantidad                             12
# fecha_venta                         364
# categoria                             3

# %%
revisar_calidad_de_datos(marketing, "Marketing")
# Out:
# ------------- Dataset de Marketing -------------
# Cantidad de duplicados: 0
# ----------------------------------------
#              Tipo de dato  Cantidad de nulos  Porcentaje de nulos  \
# id_campanha         int64                  0                  0.0
# producto           object                  0                  0.0
# canal              object                  0                  0.0
# costo             float64                  0                  0.0
# fecha_inicio       object                  0                  0.0
# fecha_fin          object                  0                  0.0
#
#               Cantidad de valores unicos
# id_campanha                           90
# producto                              30
# canal                                  3
# costo                                 81
# fecha_inicio                          78
# fecha_fin                             78

# %% [markdown]
# # ⚙️ Etapa 2

# %% [markdown]
# ### Limpieza de texto

# %%
def normalizar_texto(texto):
  '''
  Convertir texto a minusculas, quitar tildes y espcacios extras
  '''
  if not isinstance(texto, str):
    return texto;
  texto = texto.lower();
  reemplazos = {
        "á": "a", "é": "e", "í": "i", "ó": "o", "ú": "u",
        "ä": "a", "ë": "e", "ï": "i", "ö": "o", "ü": "u",
        "ñ": "n"
  }
  for acento, sin_acento in reemplazos.items():
      texto = texto.replace(acento, sin_acento);
  texto = texto.strip();
  return texto;

# %% [markdown]
# ### Limpieza general de datos

# %%
def limpiar_datos(data, columnas=None):
  data = data.copy();
  data = data.drop_duplicates();
  if columnas:
    for columna in columnas:
      if columna in data.columns: data[columna] = data[columna].astype(str).apply(normalizar_texto)
  return data;

cliente_limpio= limpiar_datos(clientes, columnas=['nombre', 'ciudad'])
venta_limpio = limpiar_datos(ventas, columnas=['producto', 'categoria'])
marketing_limpio = limpiar_datos(marketing, columnas=['canal_venta', 'canal'])

print("-----------------------------------------------------------------------")
print("limpieza completa.")
print("------------------------------- Clientes -------------------------------")
display(cliente_limpio.head())
print("------------------------------- Ventas -------------------------------")
display(venta_limpio.head())
print("------------------------------ Marketing -------------------------------")
display(marketing_limpio.head())
# Out:
# -----------------------------------------------------------------------
# limpieza completa.
# ------------------------------- Clientes -------------------------------
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      aloysia screase    44  mar del plata  42294.68
# 1           2  kristina scaplehorn    25        posadas  24735.04
# 2           3       filip castagne    50    resistencia  35744.85
# 3           4          liuka luard    39   bahia blanca  27647.96
# 4           5        dore cockshtt    28        rosario  28245.65
# ------------------------------- Ventas -------------------------------
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    lampara de mesa  $105.10       5.0  02/01/2024
# 2      1156           secadora   $97.96       3.0  02/01/2024
# 3      1372           heladera  $114.35       8.0  02/01/2024
# ...

# %% [markdown]
# ### Transformacion de datos

# %%
if 'monto' in venta_limpio.columns:
  p80 = venta_limpio['monto'].quantile(0.8)
  top_ventas = venta_limpio[venta_limpio['monto'] >= p80]
  print(f"Producto con ventas mayot igual a percentil 80 ({p80:.2f}) ")
  print(top_ventas.head())

# %% [markdown]
# ### Agregacion

# %%
if {'producto', 'monto'}.issubset(venta_limpio.columns):
    resumen_ventas = (
        venta_limpio.groupby('producto')
                     .agg(total_ventas=('monto', 'sum'),
                          promedio=('monto', 'mean'),
                          cantidad=('monto', 'count'))
                     .reset_index()
                     .sort_values('total_ventas', ascending=False)
    )
    display(resumen_ventas.head())
